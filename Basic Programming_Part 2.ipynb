# %%
#to check whether the number is odd or even
def oddeve():
    while True:
        try:
            print('Enter a number to check whether it is odd or even\n')
            n1 = int(input())
            if(int(n1) %2 == 0):
                print('Number is even')
            else:
                print('Number is odd')
            break
        except ValueError:
            print('\nInvalid entery, please enter only integer value\n')
        
#to check whether number is prime or not        
def prime_check():
    while True:
        try:
              
            z= 0
            
            print('Enter a number to check whether it is prime or not\n')
            a = int(input())
            for i in range(1, int(a+1)):
                if(int(a) % int(i) == 0):
                    z = z+1
            if z == 2:
                print('The number is prime')
            else:
                print('The number aint prime')
            z= 0 
            break
        except ValueError:
            print('Invalid entery, please enter a valid integer\n')
    
def print_oddeve():
    print('\nThank you, now:\n')
    N = int(input('Please enter the limit till you would like to compute odd or even numbers\n'))
    
    print('\nNow select whether you would like to print even or odd numbers\n')
    string = input('Enter "E" for Even numbers, "O" for Odd numbers\n')
    
    E =[]
    O =[]
    
    for i in range(0,N+1):
        if(i%2 == 0):
            E.append(int(i))    
        else:
            O.append(int(i))
          
    if string == 'E':
        print(E)
       
    if string == 'O':
        print(O) 
        
def print_prime():
    L = []
    I = []
    J = []
    Z = []
    z=0
    
    print('Given the number N, first N prime numbers\n')
    N = int(input())
    #print(L,z)
    for i in range(1,N+1):
        #print(i)
        I.append(i)
        for j in range(1, i+1):
            #print(j)
            J.append(j)
            if(int(i) % int(j) == 0):
                z = z+1
                Z.append(z)
            #print(z)
        if z == 2:
            L.append(i)
            
        z=0
    #print(I,J,Z)
    print('\nYour prime numbers are:\n')
    print(L)
    
#function to calculate factorial     
def factorial():
    print('Enter the number to calculate factorial\n')
    n=int(input())

    def fact1(n):
        if(n == 0):
            return 1
        else:
            return n*fact1(n-1)
    print('\nYour factorial is:')
         
    print(fact1(n))
#factorial()
    
    
# main code 
str1 = "Y"

while str1 == "Y":
    
    print('\nWelcome, pick an operation you would like to perform\n')
    print('Press 1, to check whether entered number is odd or even\n')
    print('Press 2, to check whether entered number is prime or not\n')
    print('Press 3, to print the the first N odd or even integers \n')
    print('Press 4, to print first N prime numbers\n')
    print('Press 5, to print the factorial of an integer\n')


    choice = input('\nEnter your choice here\n')
    
    if int(choice) == 1:
        oddeve()
    else:
        if int(choice) == 2:
            prime_check()
        else:
            if int(choice) == 3:
                print_oddeve()
            else:
                if int(choice) == 4:
                    print_prime()
                else:
                    if int(choice) == 5:
                        factorial()
                    else:
                        print('\nInvalid entry, please enter an integer between 1 to 5')
    str1 = str(input('\nDo you want to continue? Y/N\n'))
# Out:
# Welcome, pick an operation you would like to perform
#
# Press 1, to check whether entered number is odd or even
#
# Press 2, to check whether entered number is prime or not
#
# Press 3, to print the the first N odd or even integers
#
# Press 4, to print first N prime numbers
#
# Press 5, to print the factorial of an integer
#
#
# Enter your choice here
# 7
#
# Invalid entry, please enter an integer between 1 to 5
#
# Do you want to continue? Y/N
# Y
#
# Welcome, pick an operation you would like to perform
#
# Press 1, to check whether entered number is odd or even
#
# Press 2, to check whether entered number is prime or not
#
# Press 3, to print the the first N odd or even integers
#
# Press 4, to print first N prime numbers
#
# Press 5, to print the factorial of an integer
#
#
# Enter your choice here
# 5
# Enter the number to calculate factorial
#
# 8
#
# Your factorial is:
# 40320
#
# Do you want to continue? Y/N
# Y
#
# Welcome, pick an operation you would like to perform
#
# ...
